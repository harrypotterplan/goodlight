# %% [markdown]
# <a href="https://colab.research.google.com/github/harrypotterplan/goodlight/blob/main/%EC%BB%B4%ED%93%A8%ED%84%B0%EB%B9%84%EC%A0%BC_%EB%93%B1%EB%93%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
import requests

# %%
requests.get('http://naver.com')
# Out:
# <Response [200]>

# %%
request,get('http://naver.com').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ea1c740b7de6> in <module>
# ----> 1 request,get('http://naver.com').text
#
# NameError: name 'request' is not defined

# %%
requests.get('http://naver.com').text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
image_url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQiYZd8pw0ognsm2fRlk9NanO9x2emkqkrW_g&usqp=CAU'

# %%
from PIL import Image
from io import ByteIO
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-76d14083134d> in <module>
#       1 from PIL import Image
# ----> 2 from io import ByteIO
#
# ImportError: cannot import name 'ByteIO' from 'io' (/usr/lib/python3.8/io.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from PIL import Image
from io import BytesIO

# %%
requests.get(image_url).content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x12\x13\x12\x15\x13\x13\x12\x15\x16\x15\x16\x18\x17\x17\x17\x18\x18\x17\x17\x17\x16\x18\x18\x15\x15\x18\x17\x17\x18\x17\x18\x18\x1d( \x18\x1a%\x1d\x17\x15!1!%)+...\x17\x1f383,7(-.+\x01\n\n\n\x0e\r\x0e\x1a\x10\x10\x1a-%\x1f%----------------------------------------------+---\xff\xc0\x00\x11\x08\x00\xa8\x01+\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x00\x01\x05\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x01\x02\x03\x04\x06\x00\x07\xff\xc4\x00>\x10\x00\x01\x03\x02\x04\x03\x06\x05\x02\x05\x03\x03\x05\x01\x00\x00\x01\x00\x02\x11\x03!\x04\x121A\x05Qa"q\x81\x91\xa1\xf0\x062\xb1\xc1\xd1\x13\xe1\x14#BR\xf1\x07\x15b3\x92\xa2Cr\x82\xb2\xf2\x16\xff\xc4\x00\x18\x01\x00\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\xff\xc4\x00 \x11\x00\x02\x02\x02\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x11!1\x03\x12AQ\x13"q\xff\xda\x0
# ...

# %%
temp=requests.get(image_url).content

# %%
tempByte = ByteIO(temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-32a40f4025c2> in <module>
# ----> 1 tempByte = ByteIO(temp)
#
# NameError: name 'ByteIO' is not defined

# %%
tempByte = BytesIO(temp)

# %%
image=Image.open(tempByte)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x168 at 0x7F0C76EF2F70>

# %%
imgae=Image.open(BytesIO(requests.get(image_url).content))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x168 at 0x7F0C76EF2F70>

# %%
key ='dcabc1690d5b4f66a4bdc1fcd28f9f9e'
endpoint='https://labuser36cv.cognitiveservices.azure.com/'

# %%
endpoint = endpoint +'vision/v2.0/'

# %%
analyzeEndpotin = endpoint +'analyze'

# %%
headers = {'Ocp-Apim-Subscription-Key': key}
params = {'visualFeatures':'Categories,Description,Color'}
data={'url':image_url}

# %%
requests.post(analyzeEndpotin,
              hearders=headers,
              params=params,
              json=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-26a044378360> in <module>
# ----> 1 requests.post(analyzeEndpotin,
#       2               hearders=headers,
#       3               params=params,
#       4               json=data)
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# TypeError: request() got an unexpected keyword argument 'hearders'

# %%
respones = requests.post(analyzeEndpotin,
              hearders=headers,
              params=params,
              json=data)
respones
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-43707a448dee> in <module>
# ----> 1 respones = requests.post(analyzeEndpotin,
#       2               hearders=headers,
#       3               params=params,
#       4               json=data)
#       5 respones
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# TypeError: request() got an unexpected keyword argument 'hearders'

# %%
respones = requests.post(analyzeEndpotin,
              hearders=headers,
              params=params,
              json=data)
respones
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-43707a448dee> in <module>
# ----> 1 respones = requests.post(analyzeEndpotin,
#       2               hearders=headers,
#       3               params=params,
#       4               json=data)
#       5 respones
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# TypeError: request() got an unexpected keyword argument 'hearders'

# %%
key ='dcabc1690d5b4f66a4bdc1fcd28f9f9e'
endpoint='https://labuser36cv.cognitiveservices.azure.com/'
endpoint = endpoint + 'vision/v2.0/'
analyzeEndpoont = endpoint + 'analyze'
headers = {'Ocp-Apim-Subscription-Key': key}
params = {'visualFeatures':'Categories,Description,Color'}
data = {'url':image_url}
response = requests.post(analyzeEndpoont,
              headers=headers,
              params=params,
              json=data)

# %%
response.json()
# Out:
# {'categories': [{'name': 'animal_dog', 'score': 0.98046875}],
#  'color': {'dominantColorForeground': 'White',
#   'dominantColorBackground': 'White',
#   'dominantColors': ['White', 'Brown'],
#   'accentColor': '896442',
#   'isBwImg': False,
#   'isBWImg': False},
#  'description': {'tags': ['cat',
#    'laying',
#    'indoor',
#    'animal',
#    'mammal',
#    'lying',
#    'brown',
#    'bed',
#    'dog',
#    'sitting',
#    'large',
#    'sleeping',
#    'eyes'],
#   'captions': [{'text': 'a cat lying on a bed',
#     'confidence': 0.8166131922749864}]},
#  'requestId': '9c8f3d74-c270-4c1c-8fb9-2c0501618193',
#  'metadata': {'height': 168, 'width': 299, 'format': 'Jpeg'}}

# %%
result = response.json()

# %%
result
# Out:
# {'categories': [{'name': 'animal_dog', 'score': 0.98046875}],
#  'color': {'dominantColorForeground': 'White',
#   'dominantColorBackground': 'White',
#   'dominantColors': ['White', 'Brown'],
#   'accentColor': '896442',
#   'isBwImg': False,
#   'isBWImg': False},
#  'description': {'tags': ['cat',
#    'laying',
#    'indoor',
#    'animal',
#    'mammal',
#    'lying',
#    'brown',
#    'bed',
#    'dog',
#    'sitting',
#    'large',
#    'sleeping',
#    'eyes'],
#   'captions': [{'text': 'a cat lying on a bed',
#     'confidence': 0.8166131922749864}]},
#  'requestId': '9c8f3d74-c270-4c1c-8fb9-2c0501618193',
#  'metadata': {'height': 168, 'width': 299, 'format': 'Jpeg'}}

# %%
result['description']['captions'][0]
# Out:
# {'text': 'a cat lying on a bed', 'confidence': 0.8166131922749864}

# %%
result['description']['captions'][0]['text']
# Out:
# 'a cat lying on a bed'

# %%
detectEndpoint = endpoint+'detect'

# %%
response = requests.post(detectEndpoint,
              headers=headers,
              params=params,
              json=data)

# %%
response.json()
# Out:
# {'categories': [{'name': 'animal_dog', 'score': 0.98046875}],
#  'color': {'dominantColorForeground': 'White',
#   'dominantColorBackground': 'White',
#   'dominantColors': ['White', 'Brown'],
#   'accentColor': '896442',
#   'isBwImg': False,
#   'isBWImg': False},
#  'description': {'tags': ['cat',
#    'laying',
#    'indoor',
#    'animal',
#    'mammal',
#    'lying',
#    'brown',
#    'bed',
#    'dog',
#    'sitting',
#    'large',
#    'sleeping',
#    'eyes'],
#   'captions': [{'text': 'a cat lying on a bed',
#     'confidence': 0.8166131922749864}]},
#  'requestId': '9c8f3d74-c270-4c1c-8fb9-2c0501618193',
#  'metadata': {'height': 168, 'width': 299, 'format': 'Jpeg'}}

# %%
print()

# %%
result = response.json()
def MakeRetangle(result):
  objects = result['objects']

  print(objects)

# %%
MakeRetangle(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-af3e2ed27a01> in <module>
# ----> 1 MakeRetangle(result)
#
# <ipython-input-33-ad6064ce3cf0> in MakeRetangle(result)
#       1 result = response.json()
#       2 def MakeRetangle(result):
# ----> 3   objects = result['objects']
#       4
#       5   print(objects)
#
# KeyError: 'objects'

# %%
result = response.json()
def MakeRetangle(result):
  objects = result['objects']

  for obj in objects:
    rect=obj['rectangle']
    print(rect)

# %%
MakeRetangle(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-af3e2ed27a01> in <module>
# ----> 1 MakeRetangle(result)
#
# <ipython-input-35-931f70a169ab> in MakeRetangle(result)
#       1 result = response.json()
#       2 def MakeRetangle(result):
# ----> 3   objects = result['objects']
#       4
#       5   for obj in objects:
#
# KeyError: 'objects'

# %%
result = response.json()
def MakeRetangle(result):
  objects = result['objects']

  for obj in objects:
    rect=obj['rectangle']
    print(rect)
    x=rect['x']
    y=rect['y']
    w=rect['w']
    h=rect['h']

from PIL import Image, ImageDraw, ImageFont

# %%
MakeRetangle(result)
# Out:
# {'x': 173, 'y': 68, 'w': 126, 'h': 99}
# {'x': 2, 'y': 0, 'w': 208, 'h': 140}

# %%
result = response.json()
def MakeRetangle(result):
  objects = result['objects']

  for obj in objects:
    rect=obj['rectangle']
    print(rect)
    x=rect['x']
    y=rect['y']
    w=rect['w']
    h=rect['h']

    draw.rectangle(((x,y),(x+w,y+h)),outline='red')
    objec
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66dc89a47cc3> in <module>
# ----> 1 result = response.json()
#       2 def MakeRetangle(result):
#       3   objects = result['objects']
#       4
#       5   for obj in objects:
#
# NameError: name 'response' is not defined

# %%
from PIL import Image, ImageDraw, ImageFont
draw = ImageDraw.Draw(image)

# %%
MakeRetangle(result)

# %%
image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-28935580a9bb> in <module>
# ----> 1 image
#
# NameError: name 'image' is not defined
